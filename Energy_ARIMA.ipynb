# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv('Energy-ARIMA.csv')

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])
data.set_index('timestamp', inplace=True)

# %%
print(data.head())
# Out:
#                        load       temp
# timestamp
# 2012-01-01 00:00:00  2698.0  32.000000
# 2012-01-01 01:00:00  2558.0  32.666667
# 2012-01-01 02:00:00  2444.0  30.000000
# 2012-01-01 03:00:00  2402.0  31.000000
# 2012-01-01 04:00:00  2403.0  32.000000

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['load'], color='blue')
plt.title('Energy Load Time Series')
plt.xlabel('Timestamp')
plt.ylabel('Load')
plt.show()

# %%
def adf_test(series):
    result = adfuller(series)
    print('ADF Statistic: {:.3f}'.format(result[0]))
    print('p-value: {:.3f}'.format(result[1]))
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t{}: {:.3f}'.format(key, value))

# %%
print('Augmented Dickey-Fuller Test for Load:')
adf_test(data['load'])
# Out:
# Augmented Dickey-Fuller Test for Load:
# ADF Statistic: -10.404
# p-value: 0.000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
